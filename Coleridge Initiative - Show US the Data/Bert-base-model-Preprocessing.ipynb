# %%
import os
import pandas as pd
import numpy as np
import json
import re
from nltk.tokenize import sent_tokenize 
from transformers import BertTokenizer, AutoTokenizer
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import transformers
from tqdm import tqdm
import glob

import datetime 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Config

# %%
platform = 'Sage'
model_name = 'bert_base_uncased.bin'

if platform == 'Azure':
    bert_path = '/home/thanish/transformer_models/bert_base_uncased'
    test_path = '../test/*'
    model_path = '../output/' + model_name
elif platform == 'Kaggle':
    bert_path = '../input/bertlargeuncasedpytorch'
    test_path = '/kaggle/input/coleridgeinitiative-show-us-the-data/test/*'
    model_path = '../input/coleridgemodels/'+ model_name
else:
    bert_path = 'C:/Users/thanisb/Documents/transformer_models/bert_base_uncased/'
    test_path = '../test/*'
    model_path = '../output/' + model_name
    
config = {'MAX_LEN':128,
          'tokenizer': AutoTokenizer.from_pretrained('bert-base-uncased' , do_lower_case=True),
          'batch_size':5,
          'Epoch': 10,
          'test_path':test_path, 
          'device': 'cuda' if torch.cuda.is_available() else 'cpu',
          'model_path':model_path
         }

# %% [markdown]
# # Reading the train csv

# %%
train = pd.read_csv("../train.csv")
train
# Out:
#                                          Id  \
# 0      d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1      2f26f645-3dec-485d-b68d-f013c9e05e60
# 2      c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3      5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4      c754dec7-c5a3-4337-9892-c02158475064
# ...                                     ...
# 19656  b3498176-8832-4033-aea6-b5ea85ea04c4
# 19657  f77eb51f-c3ac-420b-9586-cb187849c321
# 19658  ab59bcdd-7b7c-4107-93f5-0ccaf749236c
# 19659  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 19660  fd23e7e0-a5d2-4f98-992d-9209c85153bb
#
#                                                pub_title  \
# 0      The Impact of Dual Enrollment on College Degre...
# 1      Educational Attainment of High School Dropouts...
# 2      Differences in Outcomes for Female and Male St...
# 3      Stepping Stone and Option Value in a Model of ...
# 4      Parental Effort, School Resources, and Student...
# ...                                                  ...
# 19656  RSNA International Trends: A Global Perspectiv...
# 19657  MCCS: a novel recognition pattern-based method...
# 19658  Quantitative Structure–Activity Relationship M...
# 19659  A ligand-based computational drug repurposing ...
# 19660  A ligand-based computational drug repurposing ...
#
#                                            dataset_title  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656  RSNA International COVID-19 Open Radiology Dat...
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660  CAS COVID-19 antiviral candidate compounds dat...
#
#                                            dataset_label  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656   RSNA International COVID Open Radiology Database
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660    CAS COVID-19 antiviral candidate compounds data
#
#                                            cleaned_label
# 0                  national education longitudinal study
# 1                  national education longitudinal study
# 2                  national education longitudinal study
# 3                  national education longitudinal study
# 4                  national education longitudinal study
# ...                                                  ...
# 19656   rsna international covid open radiology database
# 19657  cas covid 19 antiviral candidate compounds dat...
# 19658  cas covid 19 antiviral candidate compounds dat...
# 19659  cas covid 19 antiviral candidate compounds dat...
# 19660    cas covid 19 antiviral candidate compounds data
#
# [19661 rows x 5 columns]

# %% [markdown]
# # Getting the extra label

# %%
extra_label_800 = pd.read_csv("../extra_data/data_set_800.csv")
extra_label_26897 = pd.read_csv("../extra_data/data_set_26897.csv")

print(extra_label_26897.shape)
print(extra_label_800.shape)

extra_label_final = pd.concat([extra_label_26897, extra_label_800]).reset_index(drop=True)
print(extra_label_final.shape)

extra_label_final.title = extra_label_final.title.apply(lambda x: clean_text(x))

# Removing the train label
unique_extra_label_final = np.setdiff1d(extra_label_final.title, train.cleaned_label)
print(unique_extra_label_final.shape)
# Out:
# (26896, 1)
# (2339, 1)
# (29235, 1)
# (23500,)

# %% [markdown]
# # Combining the labels together

# %%
train_df = train.groupby(['Id']).agg(label_count = ('cleaned_label', 'count'),
                                     label = ('cleaned_label', '|'.join)).reset_index()
train_df
# Out:
#                                          Id  label_count  \
# 0      0007f880-0a9b-492d-9a58-76eb0b0e0bd7            1
# 1      0008656f-0ba2-4632-8602-3017b44c2e90            1
# 2      000e04d6-d6ef-442f-b070-4309493221ba            1
# 3      000efc17-13d8-433d-8f62-a3932fe4f3b8            2
# 4      0010357a-6365-4e5f-b982-582e6d32c3ee            1
# ...                                     ...          ...
# 14311  ffd19b3c-f941-45e5-9382-934b5041ec96            1
# 14312  ffd4d86a-0f26-44cc-baed-f0e209cc22af            1
# 14313  ffe7f334-245a-4de7-b600-d7ff4e28bfca            1
# 14314  ffeb3568-7aed-4dbe-b177-cbd7f46f34af            1
# 14315  ffee2676-a778-4521-b947-e1e420b126c5            2
#
#                                                    label
# 0      program for the international assessment of ad...
# 1      trends in international mathematics and scienc...
# 2               agricultural resources management survey
# 3      adni|alzheimer s disease neuroimaging initiati...
# 4                            genome sequence of covid 19
# ...                                                  ...
# 14311                              census of agriculture
# 14312  alzheimer s disease neuroimaging initiative adni
# 14313                     genome sequences of sars cov 2
# 14314  trends in international mathematics and scienc...
# 14315  beginning postsecondary student|beginning post...
#
# [14316 rows x 3 columns]

# %% [markdown]
# # Reading all the json train files

# %%
def read_all_json(df):
    '''
    This function reads all the json input files and return a dictionary containing the id as the key
    and all the contents of the json as values
    '''
    text_data = {}
    for i, rec_id in tqdm(enumerate(df.Id), total = len(df.Id)):
        location = f'../train/{rec_id}.json'

        with open(location, 'r') as f:
            text_data[rec_id] = json.load(f)
        
    print("All files read")
    end = datetime.datetime.now()
    
    return text_data

# %%
# %time 
data_dict = read_all_json(df=train_df)
# Out:
#   4%|▍         | 576/14316 [00:00<00:02, 5758.73it/s]
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.63 µs
# 100%|██████████| 14316/14316 [00:02<00:00, 5434.17it/s]
# All files read

# %%
def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower()).strip()

# %%
def data_joining(data_dict_id):
    '''
    This function is to join all the text data from different sections in the json to a single
    text file. 
    '''
    data_length = len(data_dict_id)

    #     temp = [clean_text(data_dict_id[i]['text']) for i in range(data_length)]
    temp = [data_dict_id[i]['text'] for i in range(data_length)]
    temp = '. '.join(temp)
    
    return temp

# %%
def make_shorter_sentence(sentence):
    sent_tokenized = sent_tokenize(sentence)
    
    max_length = config['MAX_LEN']
    overlap = 20
    
    final_sentences = []
    
    for tokenized_sent in sent_tokenized:
        sent_tokenized_clean = clean_text(tokenized_sent)
        sent_tokenized_clean = sent_tokenized_clean.replace('.','').rstrip() 
        
        tok_sent = sent_tokenized_clean.split(" ")
        
        if len(tok_sent)<max_length:
            final_sentences.append(sent_tokenized_clean)
        else :
#             print("Making shorter sentences")
            start = 0
            end = len(tok_sent)
            
            for i in range(start, end, max_length-overlap):
                temp = tok_sent[i: (i + max_length)]
                final_sentences.append(" ".join(i for i in temp))

    return final_sentences

# %%
# This is the original sentence

def form_labels(sentence, labels_list):
    '''
    This function labels the training data 
    '''
    matched_kwords = []
    matched_token = []
    un_matched_kwords = []
    label = []

    # Since there are many sentences which are more than 512. Let's make the max length of all
    # the sentences be 64
    tokens = make_shorter_sentence(sentence)
    
    for tok in tokens:    
        tok_split = config['tokenizer'].tokenize(tok)
        
        z = np.array(['O'] * len(tok_split)) # Create final label == len(tokens) of each sentence
        matched_keywords = 0 # Initially no kword matched    

        for kword in labels_list:
            kword_split = config['tokenizer'].tokenize(kword)
            for i in range(len(tok_split)):
                if tok_split[i: (i + len(kword_split))] == kword_split:
                    matched_keywords += 1
#                     print("matched keyword with token:", tok_split[i: (i+len(kword_split))] )
#                     print(tok_split)

                    if (len(kword_split) == 1):
                        z[i] = 'B'
                    else:
                        z[i] = 'B'
                        z[(i+1) : (i+ len(kword_split))]= 'B'

                    if matched_keywords >1:
                        label[-1] = (z.tolist())
                        matched_token[-1] = tok
                        matched_kwords[-1].append(kword)
                    else:
                        label.append(z.tolist())
                        matched_token.append(tok)
                        matched_kwords.append([kword])
                    #print(label[-1])
                    #print("")
    #                 break
                else:
                    un_matched_kwords.append(tok)
                
    return matched_token, matched_kwords, label, un_matched_kwords

# %%
def labelling(dataset, data_dict):
    
    Id_list_ = []
    sentences_ = []
    key_ = []
    labels_ = []
    un_mat = []
    un_matched_reviews = 0

    for i, Id in tqdm(enumerate(dataset.Id), total=len(dataset.Id)):

        sentence = data_joining(data_dict[Id])
        labels = train_df.label[train_df.Id == Id].tolist()[0].split("|")

        s, k, l, un_matched = form_labels(sentence=sentence, labels_list = labels)

        if len(s) == 0:
            un_matched_reviews += 1
            un_mat.append(un_matched)
        else: 
            sentences_.append(s)
            key_.append(k)
            labels_.append(l)
            Id_list_.append([Id]*len(l))

        if (i%100) == 0:
            print(f"Completed {i}/{train_df.Id.shape[0]}")

    print("Total unmatched keywords:", un_matched_reviews)
    sentences = [item for sublist in sentences_ for item in sublist]
    final_labels = [item for sublist in labels_ for item in sublist]
    keywords = [item for sublist in key_ for item in sublist]
    Id_list = [item for sublist in Id_list_ for item in sublist]
    
    return sentences, final_labels, keywords, Id_list

# %%
train_sentences, train_labels, train_keywords, train_Id_list = labelling(dataset = train_df, data_dict=data_dict)
valid_sentences, valid_labels, valid_keywords, valid_Id_list = labelling(dataset = DF_valid)

print("")
print(f" train sentences: {len(train_sentences)}, train label: {len(train_labels)}, train keywords: {len(train_keywords)}, train_id list: {len(train_Id_list)}")

# %% [markdown]
# # Create DataFrame to remove the duplicates

# %%
unique_df = pd.DataFrame({'id':train_Id_list, 
                          'train_sentences': train_sentences, 
                          'kword': train_keywords, 
                          'label':train_labels})
unique_df.label = unique_df.label.astype('str')
unique_df.kword = unique_df.kword.astype('str')
unique_df['sent_len'] = unique_df.train_sentences.apply(lambda x : len(x.split(" ")))
unique_df.head(60)
# Out:
#                                       id  \
# 0   0007f880-0a9b-492d-9a58-76eb0b0e0bd7
# 1   0008656f-0ba2-4632-8602-3017b44c2e90
# 2   000e04d6-d6ef-442f-b070-4309493221ba
# 3   000e04d6-d6ef-442f-b070-4309493221ba
# 4   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 5   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 6   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 7   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 8   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 9   000efc17-13d8-433d-8f62-a3932fe4f3b8
# 10  000efc17-13d8-433d-8f62-a3932fe4f3b8
# 11  000efc17-13d8-433d-8f62-a3932fe4f3b8
# 12  000efc17-13d8-433d-8f62-a3932fe4f3b8
# 13  000efc17-13d8-433d-8f62-a3932fe4f3b8
# 14  0010357a-6365-4e5f-b982-582e6d32c3ee
# 15  002203f0-1c57-4400-abc1-b783c4085743
# 16  002203f0-1c57-4400-abc1-b783c4085743
# 17  002203f0-1c57-4400-abc1-b783c4085743
# 18  00243b98-f868-45e4-9b83-0c346c7ecad5
# 19  00243b98-f868-45e4-9b83-0c346c7ecad5
# 20  00248da3-ac1d-48fa-a95e-cc88553f9583
# 21  00248da3-ac1d-48fa-a95e-cc88553f9583
# 22  0026563b-d5b3-417d-bd25-7656b97a044f
# 23  002b53ee-5b30-497f-a2fd-56885563918c
# 24  002cbf56-5158-4ec7-83fd-51fa7829bb13
# 25  002fdc24-9ee2-42b5-b051-373faca90c4e
# 26  002fdc24-9ee2-42b5-b051-373faca90c4e
# 27  002fdc24-9ee2-42b5-b051-373faca90c4e
# 28  002fdc24-9ee2-42b5-b051-373faca90c4e
# 29  002fdc24-9ee2-42b5-b051-373faca90c4e
# 30  002fdc24-9ee2-42b5-b051-373faca90c4e
# 31  002fdc24-9ee2-42b5-b051-373faca90c4e
# 32  002fdc24-9ee2-42b5-b051-373faca90c4e
# 33  002fdc24-9ee2-42b5-b051-373faca90c4e
# 34  002fdc24-9ee2-42b5-b051-373faca90c4e
# 35  002fdc24-9ee2-42b5-b051-373faca90c4e
# 36  002fdc24-9ee2-42b5-b051-373faca90c4e
# 37  002fdc24-9ee2-42b5-b051-373faca90c4e
# 38  0030f840-8505-49c0-9991-da0d4c6c9496
# 39  0030f840-8505-49c0-9991-da0d4c6c9496
# 40  0035a1ba-6d1e-487b-bc3d-d49c5d64a3e9
# 41  003822e7-b394-4d05-a32b-7c55ae9dd2e8
# 42  003822e7-b394-4d05-a32b-7c55ae9dd2e8
# 43  0041a4e4-6144-4780-a2a2-787222417a01
# 44  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 45  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 46  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 47  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 48  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 49  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 50  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 51  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 52  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 53  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 54  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 55  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 56  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 57  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 58  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 59  0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
#
#                                       train_sentences  \
# 0   in fact organizations are now identifying digi...
# 1   besides not enough young people are entering s...
# 2   1 manages access to results of the agricultura...
# 3   the agricultural resources management survey a...
# 4   genetic and neuroimaging data on a sub sample ...
# 5   this study used data from the nacc and adni da...
# 6   patient recruitment neuroimaging acquisition a...
# 7   the adni data set is from a multicenter longit...
# 8   neither other scans nor snps were assessed fro...
# 9   54 neuroimaging and genetic parameters in adni...
# 10  47 55 arterial spin labeling asl images were o...
# 11  snp rs704180 in abcc9 and apoe e4 status infor...
# 12  this was performed by measuring cbf in conveni...
# 13  despite the challenges inherent to a retrospec...
# 14  the whole genome sequence of covid 19 has abou...
# 15  this work was supported in part by the natural...
# 16  as such investigators within adni contributed ...
# 17  real clinical 1 5 t magnetization prepared rap...
# 18  the investigators used data from the early chi...
# 19  moreover and by controlling for both sociodemo...
# 20  our participants included 1196 men who perform...
# 21  our participants consisted of 1196 male partic...
# 22  during the biomass study the tide was coming i...
# 23  the participants originated in 10 cohort studi...
# 24  showed an increase in ree with the number of c...
# 25  for evaluation an age correction model was app...
# 26  the two datasets used in this study were as fo...
# 27  the 131 male and 131 female healthy subjects a...
# 28  furthermore the 25 male and 25 female ad subje...
# 29  for images downloaded from the adni database d...
# 30  briefly pet images from the adni database were...
# 31  all the results in table 5 are the average of ...
# 32   iv in the fourth test to verify whether the a...
# 33  the value declined from 1 706 08 to 1 740 10 a...
# 34  fourth in the present study we used the same t...
# 35  thus geographical differences between the two ...
# 36  the alzheimer s disease neuroimaging initiativ...
# 37  as such the investigators within the adni cont...
# 38   19 20 21 fbmc has been designated as the mc m...
# 39  12 briefly the 20 minutes of raw pet data were...
# 40  the baseline images are selected from the balt...
# 41  to further investigate the temporal consistent...
# 42  from the full adni dataset a subset of 60 age ...
# 43  2008 the noaa optimum interpolation sea surfac...
# 44  in section 2 we introduce the nih alzheimer s ...
# 45  section 5 illustrates an application of glrr i...
# 46  consider imaging genetic data from n independe...
# 47  we simulated i n d 0 and used two types of cov...
# 48        we chose actual snps from the adni data set
# 49  for n 1 000 case 500 subjects were randomly ch...
# 50  the upper left panel of figure 4 presents the ...
# 51  the development of glrr is motivated by the an...
# 52   data used in the preparation of this article ...
# 53  the adni was launched in 2003 by the national ...
# 54  the primary goal of adni has been to test whet...
# 55  adni is the result of efforts of many coinvest...
# 56  the initial goal of adni was to recruit 800 su...
# 57  the follow up duration of each group is specif...
# 58  subjects originally recruited for adni 1 and a...
# 59   for up to date information see www adni info org
#
#                                                 kword  \
# 0   ['program for the international assessment of ...
# 1   ['trends in international mathematics and scie...
# 2        ['agricultural resources management survey']
# 3        ['agricultural resources management survey']
# 4   ['adni', 'alzheimer s disease neuroimaging ini...
# 5                                            ['adni']
# 6                                            ['adni']
# 7                                            ['adni']
# 8                                            ['adni']
# 9                                    ['adni', 'adni']
# 10                                           ['adni']
# 11                                           ['adni']
# 12                                           ['adni']
# 13                                           ['adni']
# 14                    ['genome sequence of covid 19']
# 15  ['adni', 'alzheimer s disease neuroimaging ini...
# 16                                   ['adni', 'adni']
# 17                                           ['adni']
# 18             ['early childhood longitudinal study']
# 19             ['early childhood longitudinal study']
# 20          ['baltimore longitudinal study of aging']
# 21  ['baltimore longitudinal study of aging blsa '...
# 22                                ['noaa tide gauge']
# 23          ['baltimore longitudinal study of aging']
# 24  ['baltimore longitudinal study of aging blsa '...
# 25                                           ['adni']
# 26  ['adni', 'alzheimer s disease neuroimaging ini...
# 27                                           ['adni']
# 28                                           ['adni']
# 29                                           ['adni']
# 30                                           ['adni']
# 31                                           ['adni']
# 32                                           ['adni']
# 33                                           ['adni']
# 34                                           ['adni']
# 35                                           ['adni']
# 36  ['adni', 'adni', 'alzheimer s disease neuroima...
# 37                                   ['adni', 'adni']
# 38                   ['adni', 'adni', 'adni', 'adni']
# 39                                           ['adni']
# 40  ['baltimore longitudinal study of aging blsa '...
# 41                                           ['adni']
# 42                                           ['adni']
# 43  ['optimum interpolation sea surface temperatur...
# 44  ['adni', 'alzheimer s disease neuroimaging ini...
# 45                                           ['adni']
# 46                                           ['adni']
# 47                                           ['adni']
# 48                                           ['adni']
# 49                                           ['adni']
# 50                                           ['adni']
# 51                                           ['adni']
# 52  ['adni', 'adni', 'alzheimer s disease neuroima...
# 53                                           ['adni']
# 54                                           ['adni']
# 55                                           ['adni']
# 56                   ['adni', 'adni', 'adni', 'adni']
# 57                           ['adni', 'adni', 'adni']
# 58                           ['adni', 'adni', 'adni']
# 59                                           ['adni']
#
#                                                 label  sent_len
# 0   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        45
# 1   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        94
# 2   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', ...        26
# 3   ['O', 'B', 'B', 'B', 'B', 'O', 'O', 'O', 'O', ...        29
# 4   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 5   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        11
# 6   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        30
# 7   ['O', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', ...        35
# 8   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...         9
# 9   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        28
# 10  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        13
# 11  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        33
# 12  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        29
# 13  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        29
# 14  ['O', 'O', 'B', 'B', 'B', 'B', 'B', 'B', 'O', ...        16
# 15  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        36
# 16  ['O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'O', ...        28
# 17  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        75
# 18  ['O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', ...        41
# 19  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        68
# 20  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        37
# 21  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        33
# 22  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        48
# 23  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        92
# 24  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        27
# 25  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        39
# 26  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        48
# 27  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        18
# 28  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        21
# 29  ['O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', ...        28
# 30  ['O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', ...        38
# 31  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        55
# 32  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        27
# 33  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        70
# 34  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 35  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        22
# 36  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        29
# 37  ['O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', ...        19
# 38  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        39
# 39  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        55
# 40  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', ...        16
# 41  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 42  ['O', 'O', 'O', 'B', 'B', 'O', 'O', 'O', 'O', ...        21
# 43  ['O', 'O', 'B', 'B', 'B', 'B', 'B', 'B', 'B', ...        14
# 44  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', ...        14
# 45  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        19
# 46  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        10
# 47  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        32
# 48  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', ...         9
# 49  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        29
# 50  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        58
# 51  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        18
# 52  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        24
# 53  ['O', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', ...        43
# 54  ['O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'O', ...        45
# 55  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        34
# 56  ['O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'O', ...        21
# 57  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        20
# 58  ['O', 'O', 'O', 'O', 'B', 'B', 'O', 'O', 'B', ...        18
# 59  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', ...        10

# %% [markdown]
# # Write the interim dataset

# %%
unique_df.to_csv("../unique_train_df_5.csv", index=False)
