# %%
import os
import pandas as pd
import numpy as np
import json
import re
from nltk.tokenize import sent_tokenize 
from transformers import BertTokenizer, AutoTokenizer
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import transformers
from tqdm import tqdm
import glob

import datetime 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Config

# %%
platform = 'Azure'
model_name = 'model_sage_roberta_base.bin'

if platform == 'Azure':
    bert_path = '/home/thanish/transformer_models/bert_large_uncased'
    test_path = '../test/*'
    model_path = '../output/'
elif platform == 'Kaggle':
    bert_path = '../input/bertlargeuncasedpytorch'
    test_path = '/kaggle/input/coleridgeinitiative-show-us-the-data/test/*'
    model_path = '../input/coleridgemodels/'
else:
    bert_path = 'C:/Users/thanisb/Documents/transformer_models/bert_large_uncased/'
    test_path = '../test/*'
    model_path = '../output/'
    
config = {'MAX_LEN':128,
          'tokenizer': AutoTokenizer.from_pretrained('roberta-base' , do_lower_case=True),
          'batch_size':16,
          'Epoch': 15,
          'test_path':test_path, 
          'device': 'cuda' if torch.cuda.is_available() else 'cpu',
          'model_path':model_path,
          'model_name':model_name
         }

# %% [markdown]
# # Reading the train csv

# %%
train = pd.read_csv("../train.csv")
train
# Out:
#                                          Id  \
# 0      d0fa7568-7d8e-4db9-870f-f9c6f668c17b
# 1      2f26f645-3dec-485d-b68d-f013c9e05e60
# 2      c5d5cd2c-59de-4f29-bbb1-6a88c7b52f29
# 3      5c9a3bc9-41ba-4574-ad71-e25c1442c8af
# 4      c754dec7-c5a3-4337-9892-c02158475064
# ...                                     ...
# 19656  b3498176-8832-4033-aea6-b5ea85ea04c4
# 19657  f77eb51f-c3ac-420b-9586-cb187849c321
# 19658  ab59bcdd-7b7c-4107-93f5-0ccaf749236c
# 19659  fd23e7e0-a5d2-4f98-992d-9209c85153bb
# 19660  fd23e7e0-a5d2-4f98-992d-9209c85153bb
#
#                                                pub_title  \
# 0      The Impact of Dual Enrollment on College Degre...
# 1      Educational Attainment of High School Dropouts...
# 2      Differences in Outcomes for Female and Male St...
# 3      Stepping Stone and Option Value in a Model of ...
# 4      Parental Effort, School Resources, and Student...
# ...                                                  ...
# 19656  RSNA International Trends: A Global Perspectiv...
# 19657  MCCS: a novel recognition pattern-based method...
# 19658  Quantitative Structure–Activity Relationship M...
# 19659  A ligand-based computational drug repurposing ...
# 19660  A ligand-based computational drug repurposing ...
#
#                                            dataset_title  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656  RSNA International COVID-19 Open Radiology Dat...
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660  CAS COVID-19 antiviral candidate compounds dat...
#
#                                            dataset_label  \
# 0                  National Education Longitudinal Study
# 1                  National Education Longitudinal Study
# 2                  National Education Longitudinal Study
# 3                  National Education Longitudinal Study
# 4                  National Education Longitudinal Study
# ...                                                  ...
# 19656   RSNA International COVID Open Radiology Database
# 19657  CAS COVID-19 antiviral candidate compounds dat...
# 19658  CAS COVID-19 antiviral candidate compounds dat...
# 19659  CAS COVID-19 antiviral candidate compounds dat...
# 19660    CAS COVID-19 antiviral candidate compounds data
#
#                                            cleaned_label
# 0                  national education longitudinal study
# 1                  national education longitudinal study
# 2                  national education longitudinal study
# 3                  national education longitudinal study
# 4                  national education longitudinal study
# ...                                                  ...
# 19656   rsna international covid open radiology database
# 19657  cas covid 19 antiviral candidate compounds dat...
# 19658  cas covid 19 antiviral candidate compounds dat...
# 19659  cas covid 19 antiviral candidate compounds dat...
# 19660    cas covid 19 antiviral candidate compounds data
#
# [19661 rows x 5 columns]

# %% [markdown]
# # Combining the labels together

# %%
train_df = train.groupby(['Id']).agg(label_count = ('cleaned_label', 'count'),
                                     label = ('cleaned_label', '|'.join)).reset_index()
train_df
# Out:
#                                          Id  label_count  \
# 0      0007f880-0a9b-492d-9a58-76eb0b0e0bd7            1
# 1      0008656f-0ba2-4632-8602-3017b44c2e90            1
# 2      000e04d6-d6ef-442f-b070-4309493221ba            1
# 3      000efc17-13d8-433d-8f62-a3932fe4f3b8            2
# 4      0010357a-6365-4e5f-b982-582e6d32c3ee            1
# ...                                     ...          ...
# 14311  ffd19b3c-f941-45e5-9382-934b5041ec96            1
# 14312  ffd4d86a-0f26-44cc-baed-f0e209cc22af            1
# 14313  ffe7f334-245a-4de7-b600-d7ff4e28bfca            1
# 14314  ffeb3568-7aed-4dbe-b177-cbd7f46f34af            1
# 14315  ffee2676-a778-4521-b947-e1e420b126c5            2
#
#                                                    label
# 0      program for the international assessment of ad...
# 1      trends in international mathematics and scienc...
# 2               agricultural resources management survey
# 3      adni|alzheimer s disease neuroimaging initiati...
# 4                            genome sequence of covid 19
# ...                                                  ...
# 14311                              census of agriculture
# 14312  alzheimer s disease neuroimaging initiative adni
# 14313                     genome sequences of sars cov 2
# 14314  trends in international mathematics and scienc...
# 14315  beginning postsecondary student|beginning post...
#
# [14316 rows x 3 columns]

# %% [markdown]
# # Reading all the json train files

# %%
def read_all_json(df):
    '''
    This function reads all the json input files and return a dictionary containing the id as the key
    and all the contents of the json as values
    '''
    text_data = {}
    for i, rec_id in tqdm(enumerate(df.Id), total = len(df.Id)):
        location = f'../train/{rec_id}.json'

        with open(location, 'r') as f:
            text_data[rec_id] = json.load(f)
        
    print("All files read")
    end = datetime.datetime.now()
    
    return text_data

# %%
# %time 
data_dict = read_all_json(df=train_df)
# Out:
#   0%|▏                                                                          | 47/14316 [00:00<00:30, 467.59it/s]
# Wall time: 0 ns
# 100%|████████████████████████████████████████████████████████████████████████| 14316/14316 [00:34<00:00, 420.60it/s]
# All files read

# %%
def clean_text(txt):
    return re.sub('[^A-Za-z0-9]+', ' ', str(txt).lower()).strip()

# %%
def data_joining(data_dict_id):
    '''
    This function is to join all the text data from different sections in the json to a single
    text file. 
    '''
    data_length = len(data_dict_id)

    #     temp = [clean_text(data_dict_id[i]['text']) for i in range(data_length)]
    temp = [data_dict_id[i]['text'] for i in range(data_length)]
    temp = '. '.join(temp)
    
    return temp

# %% [markdown]
# # Get the extra label

# %%
uniq_train_label = train.cleaned_label.str.strip().unique()

extra_label_type='cleaned_extra_label'

if extra_label_type == 'raw':
    extra_label_800 = pd.read_csv("../extra_data/data_set_800.csv")
    extra_label_26897 = pd.read_csv("../extra_data/data_set_26897.csv")

    print(extra_label_800.shape)
    print(extra_label_26897.shape)

    extra_label_final = extra_label_800
    extra_label_final = pd.concat([extra_label_800, extra_label_26897]).reset_index(drop=True)
    print(extra_label_final.shape)

    extra_label_final.title = extra_label_final.title.apply(lambda x: clean_text(x))

    # Remove one word labels
    print("Remove all <2 word labels")
    extra_label_final['label_len'] = extra_label_final.title.apply(lambda x : len(x.split(" ")))
    extra_label_final = extra_label_final[extra_label_final.label_len>=3].reset_index(drop=True)
    extra_label_final
    print(extra_label_final.shape)

    # Removing the train label
    print("Remove train labels")
    unique_extra_label_final = np.setdiff1d(extra_label_final.title, uniq_train_label)
    print(unique_extra_label_final.shape)

    unique_extra_label_final = unique_extra_label_final.tolist()
    print(len(unique_extra_label_final))
    
elif extra_label_type == 'cleaned_extra_label':
    cleaned_extra_label_df = pd.read_csv("../extra_data/cleaned_extra_labels_v4.csv")
    print(cleaned_extra_label_df.shape)

    cleaned_extra_label_df.Cleaned_extra_label = cleaned_extra_label_df.Cleaned_extra_label.apply(lambda x: clean_text(x))

    # Remove one word labels
    print("Remove <3 words labels")
    cleaned_extra_label_df['label_len'] = cleaned_extra_label_df.Cleaned_extra_label.apply(lambda x : len(x.split(" ")))
    cleaned_extra_label_df = cleaned_extra_label_df[cleaned_extra_label_df.label_len>=3].reset_index(drop=True)
    print(cleaned_extra_label_df.shape)

    # Removing the train label
    print("Remove Train labels")
    unique_extra_label_final = np.setdiff1d(cleaned_extra_label_df.Cleaned_extra_label, uniq_train_label)
    print(unique_extra_label_final.shape)

    unique_extra_label_final = unique_extra_label_final.tolist()
    print(len(unique_extra_label_final))
# Out:
# (133, 2)
# Remove <3 words labels
# (132, 3)
# Remove Train labels
# (128,)
# 128

# %%
def make_shorter_sentence(sentence):
    sent_tokenized = sent_tokenize(sentence)
    
    max_length = config['MAX_LEN']
    overlap = 20
    
    final_sentences = []
    
    for tokenized_sent in sent_tokenized:
        sent_tokenized_clean = clean_text(tokenized_sent)
        sent_tokenized_clean = sent_tokenized_clean.replace('.','').rstrip() 
        
        tok_sent = sent_tokenized_clean.split(" ")
        
        if len(tok_sent)<max_length:
            final_sentences.append(sent_tokenized_clean)
        else :
#             print("Making shorter sentences")
            start = 0
            end = len(tok_sent)
            
            for i in range(start, end, max_length-overlap):
                temp = tok_sent[i: (i + max_length)]
                final_sentences.append(" ".join(i for i in temp))

    return final_sentences

# %%
# This is the original sentence

def form_labels(sentence, labels_list, extra_label_list):
    '''
    This function labels the training data 
    '''
    matched_kwords = []
    matched_token = []
    un_matched_kwords = []
    label = []

    # Since there are many sentences which are more than 512. Let's make the max length of all
    # the sentences be 64
    tokens = make_shorter_sentence(sentence)
    
    for tok in tokens:    
        tok_split = config['tokenizer'].tokenize(" " + tok)
        
        z = np.array(['O'] * len(tok_split)) # Create final label == len(tokens) of each sentence
        matched_keywords = 0 # Initially no kword matched    

        for kword in labels_list:
            if kword in tok: #This is to first check if the keyword is in the text and then go ahead
                kword_split = config['tokenizer'].tokenize(" " + kword)
                for i in range(len(tok_split)):
                    if tok_split[i: (i + len(kword_split))] == kword_split:
                        matched_keywords += 1
    #                     print("matched keyword with token:", tok_split[i: (i+len(kword_split))] )
    #                     print(tok_split)

                        if (len(kword_split) == 1):
                            z[i] = 'B'
                        else:
                            z[i] = 'B'
                            z[(i+1) : (i+ len(kword_split))]= 'B'

                        if matched_keywords >1:
                            label[-1] = (z.tolist())
                            matched_token[-1] = tok
                            matched_kwords[-1].append(kword)
                        else:
                            label.append(z.tolist())
                            matched_token.append(tok)
                            matched_kwords.append([kword])
                        #print(label[-1])
                        #print("")
        #                 break
                    else:
                        un_matched_kwords.append(tok)
                        
    return matched_token, matched_kwords, label, un_matched_kwords

# %%
def labelling(dataset, data_dict):
    
    Id_list_ = []
    sentences_ = []
    key_ = []
    labels_ = []
    un_mat = []
    un_matched_reviews = 0

    for i, Id in tqdm(enumerate(dataset.Id), total=len(dataset.Id)):
        print(Id)
        
        sentence = data_joining(data_dict[Id])
        labels = train_df.label[train_df.Id == Id].tolist()[0].split("|")

        s, k, l, un_matched = form_labels(sentence=sentence, 
                                          labels_list = labels, 
                                          extra_label_list=unique_extra_label_final)

        if len(s) == 0:
            un_matched_reviews += 1
            un_mat.append(un_matched)
        else: 
            sentences_.append(s)
            key_.append(k)
            labels_.append(l)
            Id_list_.append([Id]*len(l))

        if (i%100) == 0:
            print(f"Completed {i}/{train_df.Id.shape[0]}")

    print("Total unmatched keywords:", un_matched_reviews)
    sentences = [item for sublist in sentences_ for item in sublist]
    final_labels = [item for sublist in labels_ for item in sublist]
    keywords = [item for sublist in key_ for item in sublist]
    Id_list = [item for sublist in Id_list_ for item in sublist]
    
    return sentences, final_labels, keywords, Id_list

# %%
train_sentences, train_labels, train_keywords, train_Id_list = labelling(dataset = train_df, data_dict=data_dict)
valid_sentences, valid_labels, valid_keywords, valid_Id_list = labelling(dataset = DF_valid)

print("")
print(f" train sentences: {len(train_sentences)}, train label: {len(train_labels)}, train keywords: {len(train_keywords)}, train_id list: {len(train_Id_list)}")

# %% [markdown]
# # Create DataFrame to remove the duplicates

# %%
unique_df = pd.DataFrame({'id':train_Id_list, 
                          'train_sentences': train_sentences, 
                          'kword': train_keywords, 
                          'label':train_labels})
unique_df.label = unique_df.label.astype('str')
unique_df.kword = unique_df.kword.astype('str')
unique_df['sent_len'] = unique_df.train_sentences.apply(lambda x : len(x.split(" ")))
print(unique_df.shape)
unique_df.head(60)
# Out:
# (2370, 5)
#                                       id  \
# 0   0046e50c-6d19-4f6b-a7c5-4fe935d3b6f8
# 1   0095df80-7c87-457c-a01c-d89f9e0e1747
# 2   009a8e9d-f33c-4319-9f58-fc3e2e71e02b
# 3   00f97f4b-39e6-4b02-ab74-c1d366d3e371
# 4   00f97f4b-39e6-4b02-ab74-c1d366d3e371
# 5   0149a32f-3547-4a29-b2fb-43c9ac3fe95c
# 6   018e6c55-7704-4332-8084-ec53dc457b4b
# 7   01ab57bd-b4ad-4440-a99a-40f1f810f4cd
# 8   01ab57bd-b4ad-4440-a99a-40f1f810f4cd
# 9   01ff79c7-bb0f-4172-b7e4-401b7aedd986
# 10  01ff79c7-bb0f-4172-b7e4-401b7aedd986
# 11  01ff79c7-bb0f-4172-b7e4-401b7aedd986
# 12  0213936a-340f-47cf-a5e6-2ca353343a77
# 13  025bd0f7-e364-46c6-b1f7-7c46b180c003
# 14  025bd0f7-e364-46c6-b1f7-7c46b180c003
# 15  0284c886-7153-4599-899b-a99ddddab202
# 16  0299b2af-66a8-47df-8f8c-11ddeabf22aa
# 17  0299b2af-66a8-47df-8f8c-11ddeabf22aa
# 18  0299b2af-66a8-47df-8f8c-11ddeabf22aa
# 19  0299b2af-66a8-47df-8f8c-11ddeabf22aa
# 20  0299b2af-66a8-47df-8f8c-11ddeabf22aa
# 21  02a6f232-2e36-4993-b353-6e3d930111c5
# 22  02b90b2f-41b3-445f-88dc-a3eba8d5eb2d
# 23  02e387c8-1c79-450f-b6ac-bc3b99c046b2
# 24  02fc3630-fab1-4198-980c-3ffb4ed864b3
# 25  02fc3630-fab1-4198-980c-3ffb4ed864b3
# 26  0316321c-db1d-45a5-b0ac-c3b27a03a72a
# 27  0316321c-db1d-45a5-b0ac-c3b27a03a72a
# 28  031f9841-c9b6-45a1-b79f-5d67ffb9d321
# 29  03722e46-442e-482f-b95a-b45e02c3f789
# 30  03722e46-442e-482f-b95a-b45e02c3f789
# 31  03757cfd-8292-4eed-9d0c-4cd9a2f6408c
# 32  038e65c0-3dce-4fe7-bbaa-3712fa28c4c8
# 33  043efa06-ba14-449a-a94b-1b63efeed40d
# 34  044c7bf9-5245-4480-89ce-ba721d6289c3
# 35  05364e30-5388-4025-984e-989a52d9e279
# 36  05597b34-de2b-4f91-a72f-4cd542cc34e1
# 37  05b47f78-2370-4ff2-b766-0a3dedd26a8b
# 38  05d3a5b0-3d38-4190-9d33-06ae68e3cdcf
# 39  0606313f-1f86-4520-aac9-3cfecf20db11
# 40  0619d309-cbe0-42bf-99cc-7ab0f61d59e7
# 41  0619d309-cbe0-42bf-99cc-7ab0f61d59e7
# 42  06281659-0d41-4b8a-9171-afbc9b3dbfe7
# 43  0628e1ec-74fe-4386-bcf6-1045e7912679
# 44  0628e1ec-74fe-4386-bcf6-1045e7912679
# 45  0628e1ec-74fe-4386-bcf6-1045e7912679
# 46  0649daf0-8b53-46d8-9caa-146ff8ab89c0
# 47  06511dd2-c88c-4535-a6bf-16a26641f8a5
# 48  06d4f1c3-c3d2-4149-8106-94f3640f4acf
# 49  06d4f1c3-c3d2-4149-8106-94f3640f4acf
# 50  06d4f1c3-c3d2-4149-8106-94f3640f4acf
# 51  06d4f1c3-c3d2-4149-8106-94f3640f4acf
# 52  06e76ab1-be3f-44a7-b847-53048d37efb3
# 53  0751ddb9-bf10-46b2-8844-d6633f95dbaf
# 54  075f1215-63dc-4644-b748-fa7bc1653f29
# 55  075f1215-63dc-4644-b748-fa7bc1653f29
# 56  075f1215-63dc-4644-b748-fa7bc1653f29
# 57  0768f850-bac7-4e96-a18c-2e6053a5d55b
# 58  079ea50a-d1dd-41c1-97b1-642c85e0af82
# 59  079ea50a-d1dd-41c1-97b1-642c85e0af82
#
#                                       train_sentences  \
# 0   adni is the result of efforts of many coinvest...
# 1                                     adni cohort fig
# 2   alzheimer s disease neuroimaging initiative ad...
# 3   slosh model was not used to calculate the floo...
# 4   slosh model can be downscaled to capture the s...
# 5   trends in international mathematics and scienc...
# 6   adni mueller et al 2005 into the analysis base...
# 7   adni adni loni usc edu was launched in 2003 as...
# 8    adni inclusion criteria are listed in appendix a
# 9   adni is the result of efforts of many coinvest...
# 10  adni database 40 was created to study alzheime...
# 11  adni database provides data for three groups o...
# 12           adni is not the only source of such data
# 13  adni mem was derived by confirmatory factor an...
# 14  adni ef was derived by item response theory us...
# 15  adni is the result of efforts of many co inves...
# 16  adni 2 is a multi site study that aimed to imp...
# 17  adni started in 2004 currently includes resear...
# 18  adni has been facilitating the scientific eval...
# 19  adni is the result of efforts of many research...
# 20  adni also aims to accurately track progression...
# 21  adni initially was launched in 2003 by the nat...
# 22  adni is a landmark study sponsored by the nih ...
# 23  rural urban continuum codes were used to categ...
# 24  adni is funded by the national institute on ag...
# 25  adni data are disseminated by the laboratory f...
# 26  adni participants were recruited from 58 sites...
# 27  adni subjects were scanned with a standardized...
# 28  genome sequences of sars cov 2 from western au...
# 29  sars cov 2 full genome sequences were obataine...
# 30  sars cov 2 full genome sequences available fro...
# 31  adni participant requests for amyloid imaging ...
# 32  ibtracs is a complete archive containing infor...
# 33  beginning postsecondary students longitudinal ...
# 34                                     adni track tbi
# 35  adni includes more than 800 participants rangi...
# 36  compared to 42 2 for age and sex this illustra...
# 37  adni researchers were also in favor of disclos...
# 38  alzheimer s disease neuroimaging initiative ad...
# 39  school survey on crime and safety 2017 18 data...
# 40  adni participants were genotyped using the ill...
# 41  adni info org scientists pdfs adni generalproc...
# 42  adni allows public access to all accumulating ...
# 43  adni was launched in 2004 as a collaboration i...
# 44  adni go and adni 2 added recruitment of early ...
# 45  adni 1 participants structural mri baseline sc...
# 46  alzheimer s disease neuroimaging initiative ad...
# 47  adni is funded by the national institute on ag...
# 48  adni was launched in 2003 by the national inst...
# 49  adni s goal is to test whether serial mri pet ...
# 50  adni is the result of efforts of many coinvest...
# 51  adni s goal was to recruit 800 adults ages 55 ...
# 52          survey of doctorate recipients 0 table 56
# 53  adni is the result of efforts of many coinvest...
# 54  adni is a multi centre study with data collect...
# 55  adni info org scientists pdfs adni protocol ex...
# 56  adni has the advantage of being a prospective ...
# 57  adni was launched in 2003 by the national inst...
# 58  adni was launched in 2003 by the national inst...
# 59  adni s goal is to test whether serial magnetic...
#
#                                                 kword  \
# 0                                            ['adni']
# 1                                            ['adni']
# 2   ['alzheimer s disease neuroimaging initiative ...
# 3                                     ['slosh model']
# 4                                     ['slosh model']
# 5   ['trends in international mathematics and scie...
# 6                                            ['adni']
# 7                                            ['adni']
# 8                                            ['adni']
# 9                                            ['adni']
# 10                                           ['adni']
# 11                                           ['adni']
# 12                                           ['adni']
# 13                                           ['adni']
# 14                                           ['adni']
# 15                                           ['adni']
# 16                                           ['adni']
# 17                                           ['adni']
# 18                                           ['adni']
# 19                                           ['adni']
# 20                                           ['adni']
# 21                                           ['adni']
# 22                                           ['adni']
# 23                    ['rural urban continuum codes']
# 24                                           ['adni']
# 25                                           ['adni']
# 26                                           ['adni']
# 27                                           ['adni']
# 28                 ['genome sequences of sars cov 2']
# 29               ['sars cov 2 full genome sequences']
# 30               ['sars cov 2 full genome sequences']
# 31                                           ['adni']
# 32                                        ['ibtracs']
# 33  ['beginning postsecondary students longitudina...
# 34                                           ['adni']
# 35                                           ['adni']
# 36                                    ['ixi dataset']
# 37                                           ['adni']
# 38  ['alzheimer s disease neuroimaging initiative ...
# 39              ['school survey on crime and safety']
# 40                                           ['adni']
# 41                                           ['adni']
# 42                                           ['adni']
# 43                                           ['adni']
# 44                                           ['adni']
# 45                                           ['adni']
# 46  ['alzheimer s disease neuroimaging initiative ...
# 47                                           ['adni']
# 48                                           ['adni']
# 49                                           ['adni']
# 50                                           ['adni']
# 51                                           ['adni']
# 52                 ['survey of doctorate recipients']
# 53                                           ['adni']
# 54                                           ['adni']
# 55                                           ['adni']
# 56                                           ['adni']
# 57                                           ['adni']
# 58                                           ['adni']
# 59                                           ['adni']
#
#                                                 label  sent_len
# 0   ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        34
# 1                                ['B', 'B', 'O', 'O']         3
# 2   ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', ...        23
# 3   ['B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', ...        17
# 4   ['B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', ...        14
# 5   ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', ...       128
# 6   ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        35
# 7   ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        22
# 8       ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O']         8
# 9   ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        34
# 10  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        32
# 11  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 12  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...         9
# 13  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        57
# 14  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        36
# 15  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        35
# 16  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        22
# 17  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        28
# 18  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        32
# 19  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        41
# 20  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        20
# 21  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        31
# 22  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        31
# 23  ['B', 'B', 'B', 'B', 'B', 'O', 'O', 'O', 'O', ...        28
# 24  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        95
# 25  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        19
# 26  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        10
# 27  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        21
# 28  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'O', ...        32
# 29  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'O', 'O', ...        18
# 30  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'O', 'O', ...        53
# 31  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...         7
# 32  ['B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', ...        25
# 33  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'O', 'O', ...        17
# 34                          ['B', 'B', 'O', 'O', 'O']         3
# 35  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        13
# 36  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        33
# 37  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        29
# 38  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', ...        27
# 39  ['B', 'B', 'B', 'B', 'B', 'B', 'O', 'O', 'O', ...        16
# 40  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        10
# 41  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        27
# 42      ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O']         8
# 43  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        36
# 44  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        35
# 45  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 46  ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', ...        16
# 47  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        26
# 48  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        39
# 49  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        30
# 50  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        19
# 51  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        54
# 52      ['B', 'B', 'B', 'B', 'B', 'B', 'O', 'O', 'O']         7
# 53  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        35
# 54  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        13
# 55  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        11
# 56  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        19
# 57  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        42
# 58  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        43
# 59  ['B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...        36

# %% [markdown]
# # Write the interim dataset

# %%
unique_df.to_csv("../unique_train_df_5_len_128_cleaned_extra_PWC_labels_Roberta.csv", index=False)
